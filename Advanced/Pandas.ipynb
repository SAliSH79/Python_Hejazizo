# %% [markdown]
# ### Pandas is usally used for Data Analysis

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.2'

# %%
a = [1, 2, 3.5]
my_data = pd.Series(a)
my_data
# Out:
# 0    1.0
# 1    2.0
# 2    3.5
# dtype: float64
